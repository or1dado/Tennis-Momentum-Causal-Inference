# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from dateutil.relativedelta import relativedelta

np.seed = 42

# %% [markdown]
# # Load Dataset

# %%
matches = pd.read_csv(r'Data\atp_tennis.csv')
players = pd.read_csv(r'Data\atp_players.csv')
tournament = pd.read_csv(r'Data\all_tournaments.csv')

# %% [markdown]
# # Helper Function

# %%
def merge_columns(row, player_columns):
    merged_data = {}
    columns = ['hand', 'dob', 'ioc', 'height', 'name_first', 'name_last']
    
    for col, player_col in zip(columns, player_columns):
        val1 = row[col]
        val2 = row[player_col]
        
        if pd.isna(val1) and pd.isna(val2):
            merged_data[player_col] = np.nan  # Both are NaN
        elif pd.isna(val1):
            merged_data[player_col] = val2  # Take player value if main is NaN
        elif pd.isna(val2):
            merged_data[player_col] = val1  # Take main value if player is NaN
        else:
            if val1 == val2:
                merged_data[player_col] = val1  # Take the value if both are the same
            else:
                return None  # Conflict detected, drop the row
    
    return pd.Series(merged_data)


def convert_to_date(date_str):
    try:
        # Try to convert from YYYYMMDD format
        return datetime.strptime(str(date_str), "%Y%m%d").date()
    except ValueError:
        # If it fails, try the YYYY-MM-DD format
        return datetime.strptime(str(date_str), "%Y-%m-%d").date()


def calculate_age(tournament_date, dob):
    delta = relativedelta(tournament_date, dob)
    return delta.years

# %% [markdown]
# # Filtered Data

# %%
matches = matches[(matches['Odd_1']!=-1)&(matches['Odd_2']!=-1)]
matches = matches[matches['Score'].apply(lambda x: x.split()[0] in ['6-7', '7-6'])]
matches = matches.drop_duplicates()
matches
# Out:
#                Tournament        Date         Series    Court Surface  \
# 2892   AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2899   AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2900   AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2912            TATA Open  2001-01-01  International  Outdoor    Hard
# 2917            TATA Open  2001-01-01  International  Outdoor    Hard
# ...                   ...         ...            ...      ...     ...
# 63889    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 63891    Shanghai Masters  2024-10-09        ATP1000  Outdoor    Hard
# 63899    Shanghai Masters  2024-10-10        ATP1000  Outdoor    Hard
# 63901    Shanghai Masters  2024-10-11        ATP1000  Outdoor    Hard
# 63904    Shanghai Masters  2024-10-13        ATP1000  Outdoor    Hard
#
#                Round  Best of       Player_1        Player_2          Winner  \
# 2892       2nd Round        3      Hewitt L.         Phau B.       Hewitt L.
# 2899   Quarterfinals        3   Johansson T.       Henman T.       Henman T.
# 2900   Quarterfinals        3       Massu N.     Ljubicic I.        Massu N.
# 2912       1st Round        3     Robredo T.         Paes L.      Robredo T.
# 2917       1st Round        3  Kratochvil M.  Vinciguerra A.  Vinciguerra A.
# ...              ...      ...            ...             ...             ...
# 63889      3rd Round        3  Griekspoor T.       Zverev A.       Zverev A.
# 63891      4th Round        3   Tsitsipas S.     Medvedev D.     Medvedev D.
# 63899  Quarterfinals        3     Alcaraz C.       Machac T.       Machac T.
# 63901  Quarterfinals        3      Mensik J.     Djokovic N.     Djokovic N.
# 63904      The Final        3      Sinner J.     Djokovic N.       Sinner J.
#
#        Rank_1  Rank_2  Pts_1  Pts_2     Odd_1     Odd_2        Score
# 2892        7     208     -1     -1  1.130000  5.500000  6-7 6-4 6-0
# 2899       39      10     -1     -1  2.662500  1.367500  6-7 7-6 3-6
# 2900       87      91     -1     -1  1.916667  1.653333  6-7 7-6 6-2
# 2912      131     188     -1     -1  2.000000  1.450000      7-6 6-0
# 2917       93      52     -1     -1  2.333333  1.410000      6-7 3-6
# ...       ...     ...    ...    ...       ...       ...          ...
# 63889      40       3   1305   6705  4.330000  1.220000  6-7 6-2 6-7
# 63891      12       5   3390   5375  3.000000  1.400000      6-7 3-6
# 63899       2      33   7010   1449  1.080000  8.000000      6-7 5-7
# 63901      65       4    822   5560  7.000000  1.100000  7-6 1-6 4-6
# 63904       4       4  11010   5560  1.400000  3.000000      7-6 6-3
#
# [11394 rows x 17 columns]

# %%
players = players.dropna(subset=['name_first', 'name_last', 'hand', 'ioc', 'height']).drop_duplicates().drop(columns=['wikidata_id', 'player_id'])
players['name_last'] = players['name_last'].apply(lambda x: "-".join(x.strip().split()))
players['player_name'] = players['name_last'].str.strip() + ' ' + players['name_first'].apply(
    lambda x: ''.join([name.strip()[0] + '.' for name in x.split()])
)
# players = players.drop_duplicates('player_name')
players['player_name2'] = players['player_name'].str.replace('-',' ')
players
# Out:
#            name_first   name_last hand         dob  ioc  height  \
# 0             Gardnar      Mulloy    R  19131122.0  USA   185.0
# 1              Pancho      Segura    R  19210620.0  ECU   168.0
# 2               Frank     Sedgman    R  19271002.0  AUS   180.0
# 4             Richard    Gonzalez    R  19280509.0  USA   188.0
# 5               Grant      Golden    R  19290821.0  USA   175.0
# ...               ...         ...  ...         ...  ...     ...
# 64749        Theodore     Winegar    R  20010710.0  USA   191.0
# 64753        Leonardo        Vega    R  19970904.0  USA   191.0
# 64761  Patrick Edward       Toman    R  20040629.0  USA   183.0
# 64775            Liam  Puttergill    R  20000830.0  AUS   183.0
# 64776          Matvey   Greschner    L  20041107.0  USA   196.0
#
#          player_name   player_name2
# 0          Mulloy G.      Mulloy G.
# 1          Segura P.      Segura P.
# 2         Sedgman F.     Sedgman F.
# 4        Gonzalez R.    Gonzalez R.
# 5          Golden G.      Golden G.
# ...              ...            ...
# 64749     Winegar T.     Winegar T.
# 64753        Vega L.        Vega L.
# 64761     Toman P.E.     Toman P.E.
# 64775  Puttergill L.  Puttergill L.
# 64776   Greschner M.   Greschner M.
#
# [2818 rows x 8 columns]

# %% [markdown]
# # Merge dfs

# %%
# add data on player 1
player_columns = ['hand_player1', 'dob_player1', 'ioc_player1', 'height_player1', 'name_first_player1', 'name_last_player1']
player_matches_df = matches.merge(players, left_on='Player_1', right_on='player_name', how='left', suffixes=('', '_player1')).drop(columns=['player_name'])
player_matches_df = player_matches_df.merge(players, left_on='Player_1', right_on='player_name2', how='left', suffixes=('', '_player1')).drop(columns=['player_name2'])
merged_columns = player_matches_df.apply(lambda x: merge_columns(x, player_columns), axis=1)
player_matches_df[player_columns] = merged_columns
player_matches_df.drop(columns=['hand', 'dob', 'ioc', 'height', 'name_first', 'name_last', 'player_name2_player1', 'player_name'], inplace=True)
player_matches_df = player_matches_df.dropna(subset=player_columns)

# add data on player 2
player_columns = ['hand_player2', 'dob_player2', 'ioc_player2', 'height_player2', 'name_first_player2', 'name_last_player2']
player_matches_df = player_matches_df.merge(players, left_on='Player_2', right_on='player_name', how='left', suffixes=('', '_player2')).drop(columns=['player_name'])
player_matches_df = player_matches_df.merge(players, left_on='Player_2', right_on='player_name2', how='left', suffixes=('', '_player2')).drop(columns=['player_name2'])
merged_columns = player_matches_df.apply(lambda x: merge_columns(x, player_columns), axis=1)
player_matches_df[player_columns] = merged_columns
player_matches_df.drop(columns=['hand', 'dob', 'ioc', 'height', 'name_first', 'name_last', 'player_name2_player2', 'player_name'], inplace=True)
player_matches_df = player_matches_df.dropna(subset=player_columns)

player_matches_df
# Out:
#                Tournament        Date         Series    Court Surface  \
# 0      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 1      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 3               TATA Open  2001-01-01  International  Outdoor    Hard
# 4               TATA Open  2001-01-01  International  Outdoor    Hard
# ...                   ...         ...            ...      ...     ...
# 12034    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12035    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12036    Shanghai Masters  2024-10-09        ATP1000  Outdoor    Hard
# 12037    Shanghai Masters  2024-10-10        ATP1000  Outdoor    Hard
# 12038    Shanghai Masters  2024-10-13        ATP1000  Outdoor    Hard
#
#                Round  Best of       Player_1        Player_2          Winner  \
# 0          2nd Round        3      Hewitt L.         Phau B.       Hewitt L.
# 1      Quarterfinals        3   Johansson T.       Henman T.       Henman T.
# 2      Quarterfinals        3       Massu N.     Ljubicic I.        Massu N.
# 3          1st Round        3     Robredo T.         Paes L.      Robredo T.
# 4          1st Round        3  Kratochvil M.  Vinciguerra A.  Vinciguerra A.
# ...              ...      ...            ...             ...             ...
# 12034      3rd Round        3    Dimitrov G.      Popyrin A.     Dimitrov G.
# 12035      3rd Round        3  Griekspoor T.       Zverev A.       Zverev A.
# 12036      4th Round        3   Tsitsipas S.     Medvedev D.     Medvedev D.
# 12037  Quarterfinals        3     Alcaraz C.       Machac T.       Machac T.
# 12038      The Final        3      Sinner J.     Djokovic N.       Sinner J.
#
#        ...  hand_player1  dob_player1  ioc_player1  height_player1  \
# 0      ...             R   19810224.0          AUS           180.0
# 1      ...             R   19750324.0          SWE           180.0
# 2      ...             R   19791010.0          CHI           183.0
# 3      ...             R   19820501.0          ESP           180.0
# 4      ...             R   19790407.0          SUI           185.0
# ...    ...           ...          ...          ...             ...
# 12034  ...             R   19910516.0          BUL           188.0
# 12035  ...             R   19960702.0          NED           188.0
# 12036  ...             R   19980812.0          GRE           193.0
# 12037  ...             R   20030505.0          ESP           185.0
# 12038  ...             R   20010816.0          ITA           188.0
#
#        name_first_player2  name_last_player2 hand_player2 dob_player2  \
# 0                   Bjorn               Phau            R  19791004.0
# 1                     Tim             Henman            R  19740906.0
# 2                    Ivan           Ljubicic            R  19790319.0
# 3                 Leander               Paes            R  19730617.0
# 4                 Andreas        Vinciguerra            L  19810219.0
# ...                   ...                ...          ...         ...
# 12034              Alexei            Popyrin            R  19990805.0
# 12035           Alexander             Zverev            R  19970420.0
# 12036              Daniil           Medvedev            R  19960211.0
# 12037               Tomas             Machac            R  20001013.0
# 12038               Novak           Djokovic            R  19870522.0
#
#       ioc_player2 height_player2
# 0             GER          175.0
# 1             GBR          185.0
# 2             CRO          193.0
# 3             IND          178.0
# 4             SWE          180.0
# ...           ...            ...
# 12034         AUS          196.0
# 12035         GER          198.0
# 12036         RUS          198.0
# 12037         CZE          183.0
# 12038         SRB          188.0
#
# [11018 rows x 29 columns]

# %% [markdown]
# # Choose Random Player

# %%
random_players = np.random.choice([1, 2], size=len(player_matches_df))
player_matches_df['Relevant Player'] = random_players
player_matches_df
# Out:
#                Tournament        Date         Series    Court Surface  \
# 0      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 1      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 3               TATA Open  2001-01-01  International  Outdoor    Hard
# 4               TATA Open  2001-01-01  International  Outdoor    Hard
# ...                   ...         ...            ...      ...     ...
# 12034    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12035    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12036    Shanghai Masters  2024-10-09        ATP1000  Outdoor    Hard
# 12037    Shanghai Masters  2024-10-10        ATP1000  Outdoor    Hard
# 12038    Shanghai Masters  2024-10-13        ATP1000  Outdoor    Hard
#
#                Round  Best of       Player_1        Player_2          Winner  \
# 0          2nd Round        3      Hewitt L.         Phau B.       Hewitt L.
# 1      Quarterfinals        3   Johansson T.       Henman T.       Henman T.
# 2      Quarterfinals        3       Massu N.     Ljubicic I.        Massu N.
# 3          1st Round        3     Robredo T.         Paes L.      Robredo T.
# 4          1st Round        3  Kratochvil M.  Vinciguerra A.  Vinciguerra A.
# ...              ...      ...            ...             ...             ...
# 12034      3rd Round        3    Dimitrov G.      Popyrin A.     Dimitrov G.
# 12035      3rd Round        3  Griekspoor T.       Zverev A.       Zverev A.
# 12036      4th Round        3   Tsitsipas S.     Medvedev D.     Medvedev D.
# 12037  Quarterfinals        3     Alcaraz C.       Machac T.       Machac T.
# 12038      The Final        3      Sinner J.     Djokovic N.       Sinner J.
#
#        ...  dob_player1  ioc_player1  height_player1  name_first_player2  \
# 0      ...   19810224.0          AUS           180.0               Bjorn
# 1      ...   19750324.0          SWE           180.0                 Tim
# 2      ...   19791010.0          CHI           183.0                Ivan
# 3      ...   19820501.0          ESP           180.0             Leander
# 4      ...   19790407.0          SUI           185.0             Andreas
# ...    ...          ...          ...             ...                 ...
# 12034  ...   19910516.0          BUL           188.0              Alexei
# 12035  ...   19960702.0          NED           188.0           Alexander
# 12036  ...   19980812.0          GRE           193.0              Daniil
# 12037  ...   20030505.0          ESP           185.0               Tomas
# 12038  ...   20010816.0          ITA           188.0               Novak
#
#        name_last_player2  hand_player2 dob_player2 ioc_player2 height_player2  \
# 0                   Phau             R  19791004.0         GER          175.0
# 1                 Henman             R  19740906.0         GBR          185.0
# 2               Ljubicic             R  19790319.0         CRO          193.0
# 3                   Paes             R  19730617.0         IND          178.0
# 4            Vinciguerra             L  19810219.0         SWE          180.0
# ...                  ...           ...         ...         ...            ...
# 12034            Popyrin             R  19990805.0         AUS          196.0
# 12035             Zverev             R  19970420.0         GER          198.0
# 12036           Medvedev             R  19960211.0         RUS          198.0
# 12037             Machac             R  20001013.0         CZE          183.0
# 12038           Djokovic             R  19870522.0         SRB          188.0
#
#       Relevant Player
# 0                   1
# 1                   1
# 2                   1
# 3                   2
# 4                   1
# ...               ...
# 12034               2
# 12035               2
# 12036               1
# 12037               2
# 12038               1
#
# [11018 rows x 30 columns]

# %% [markdown]
# # Extract Confounder

# %%
# age of each player
player_matches_df['Date'] = player_matches_df['Date'].apply(convert_to_date)

for player in ['1', '2']:
    player_matches_df[f'dob_player{player}'] = player_matches_df[f'dob_player{player}'].astype(int)
    player_matches_df[f'dob_player{player}'] = player_matches_df[f'dob_player{player}'].apply(convert_to_date)
    player_matches_df[f'age_player{player}'] = player_matches_df.apply(lambda row: calculate_age(row['Date'], row[f'dob_player{player}']), axis=1)

player_matches_df
# Out:
#                Tournament        Date         Series    Court Surface  \
# 0      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 1      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 3               TATA Open  2001-01-01  International  Outdoor    Hard
# 4               TATA Open  2001-01-01  International  Outdoor    Hard
# ...                   ...         ...            ...      ...     ...
# 12034    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12035    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12036    Shanghai Masters  2024-10-09        ATP1000  Outdoor    Hard
# 12037    Shanghai Masters  2024-10-10        ATP1000  Outdoor    Hard
# 12038    Shanghai Masters  2024-10-13        ATP1000  Outdoor    Hard
#
#                Round  Best of       Player_1        Player_2          Winner  \
# 0          2nd Round        3      Hewitt L.         Phau B.       Hewitt L.
# 1      Quarterfinals        3   Johansson T.       Henman T.       Henman T.
# 2      Quarterfinals        3       Massu N.     Ljubicic I.        Massu N.
# 3          1st Round        3     Robredo T.         Paes L.      Robredo T.
# 4          1st Round        3  Kratochvil M.  Vinciguerra A.  Vinciguerra A.
# ...              ...      ...            ...             ...             ...
# 12034      3rd Round        3    Dimitrov G.      Popyrin A.     Dimitrov G.
# 12035      3rd Round        3  Griekspoor T.       Zverev A.       Zverev A.
# 12036      4th Round        3   Tsitsipas S.     Medvedev D.     Medvedev D.
# 12037  Quarterfinals        3     Alcaraz C.       Machac T.       Machac T.
# 12038      The Final        3      Sinner J.     Djokovic N.       Sinner J.
#
#        ...  height_player1  name_first_player2  name_last_player2  \
# 0      ...           180.0               Bjorn               Phau
# 1      ...           180.0                 Tim             Henman
# 2      ...           183.0                Ivan           Ljubicic
# 3      ...           180.0             Leander               Paes
# 4      ...           185.0             Andreas        Vinciguerra
# ...    ...             ...                 ...                ...
# 12034  ...           188.0              Alexei            Popyrin
# 12035  ...           188.0           Alexander             Zverev
# 12036  ...           193.0              Daniil           Medvedev
# 12037  ...           185.0               Tomas             Machac
# 12038  ...           188.0               Novak           Djokovic
#
#        hand_player2  dob_player2  ioc_player2 height_player2 Relevant Player  \
# 0                 R   1979-10-04          GER          175.0               1
# 1                 R   1974-09-06          GBR          185.0               1
# 2                 R   1979-03-19          CRO          193.0               1
# 3                 R   1973-06-17          IND          178.0               2
# 4                 L   1981-02-19          SWE          180.0               1
# ...             ...          ...          ...            ...             ...
# 12034             R   1999-08-05          AUS          196.0               2
# 12035             R   1997-04-20          GER          198.0               2
# 12036             R   1996-02-11          RUS          198.0               1
# 12037             R   2000-10-13          CZE          183.0               2
# 12038             R   1987-05-22          SRB          188.0               1
#
#       age_player1 age_player2
# 0              19          21
# 1              25          26
# 2              21          21
# 3              18          27
# 4              21          19
# ...           ...         ...
# 12034          33          25
# 12035          28          27
# 12036          26          28
# 12037          21          23
# 12038          23          37
#
# [11018 rows x 32 columns]

# %%
player_matches_df = player_matches_df[(player_matches_df['age_player1']<40)&((player_matches_df['age_player2']<40))]
player_matches_df
# Out:
#                Tournament        Date         Series    Court Surface  \
# 0      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 1      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 3               TATA Open  2001-01-01  International  Outdoor    Hard
# 4               TATA Open  2001-01-01  International  Outdoor    Hard
# ...                   ...         ...            ...      ...     ...
# 12034    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12035    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12036    Shanghai Masters  2024-10-09        ATP1000  Outdoor    Hard
# 12037    Shanghai Masters  2024-10-10        ATP1000  Outdoor    Hard
# 12038    Shanghai Masters  2024-10-13        ATP1000  Outdoor    Hard
#
#                Round  Best of       Player_1        Player_2          Winner  \
# 0          2nd Round        3      Hewitt L.         Phau B.       Hewitt L.
# 1      Quarterfinals        3   Johansson T.       Henman T.       Henman T.
# 2      Quarterfinals        3       Massu N.     Ljubicic I.        Massu N.
# 3          1st Round        3     Robredo T.         Paes L.      Robredo T.
# 4          1st Round        3  Kratochvil M.  Vinciguerra A.  Vinciguerra A.
# ...              ...      ...            ...             ...             ...
# 12034      3rd Round        3    Dimitrov G.      Popyrin A.     Dimitrov G.
# 12035      3rd Round        3  Griekspoor T.       Zverev A.       Zverev A.
# 12036      4th Round        3   Tsitsipas S.     Medvedev D.     Medvedev D.
# 12037  Quarterfinals        3     Alcaraz C.       Machac T.       Machac T.
# 12038      The Final        3      Sinner J.     Djokovic N.       Sinner J.
#
#        ...  height_player1  name_first_player2  name_last_player2  \
# 0      ...           180.0               Bjorn               Phau
# 1      ...           180.0                 Tim             Henman
# 2      ...           183.0                Ivan           Ljubicic
# 3      ...           180.0             Leander               Paes
# 4      ...           185.0             Andreas        Vinciguerra
# ...    ...             ...                 ...                ...
# 12034  ...           188.0              Alexei            Popyrin
# 12035  ...           188.0           Alexander             Zverev
# 12036  ...           193.0              Daniil           Medvedev
# 12037  ...           185.0               Tomas             Machac
# 12038  ...           188.0               Novak           Djokovic
#
#        hand_player2  dob_player2  ioc_player2 height_player2 Relevant Player  \
# 0                 R   1979-10-04          GER          175.0               1
# 1                 R   1974-09-06          GBR          185.0               1
# 2                 R   1979-03-19          CRO          193.0               1
# 3                 R   1973-06-17          IND          178.0               2
# 4                 L   1981-02-19          SWE          180.0               1
# ...             ...          ...          ...            ...             ...
# 12034             R   1999-08-05          AUS          196.0               2
# 12035             R   1997-04-20          GER          198.0               2
# 12036             R   1996-02-11          RUS          198.0               1
# 12037             R   2000-10-13          CZE          183.0               2
# 12038             R   1987-05-22          SRB          188.0               1
#
#       age_player1 age_player2
# 0              19          21
# 1              25          26
# 2              21          21
# 3              18          27
# 4              21          19
# ...           ...         ...
# 12034          33          25
# 12035          28          27
# 12036          26          28
# 12037          21          23
# 12038          23          37
#
# [10598 rows x 32 columns]

# %%
# Country of the tournament

# %%
# Country of each player

# %%
# Transform round to int
map_round = {'1st Round': 1, 'Round Robin':1, '2nd Round': 2, '3rd Round': 3, '4th Round': 4}

round = []
for i in range(len(player_matches_df)):
    # print(df['Round'].iloc[i])
    if player_matches_df['Round'].iloc[i] in map_round.keys():
        round.append(map_round[player_matches_df['Round'].iloc[i]])
    else: 
        # Check previous rounds
        t = 1
        while player_matches_df['Round'].iloc[i - t] ==  player_matches_df['Round'].iloc[i]:
            t += 1
        round.append(round[i-t] + 1)  # Increment the last known round

player_matches_df['round'] = round
player_matches_df
# Out:
# C:\Users\ordad\AppData\Local\Temp\ipykernel_10164\3331321233.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_matches_df['round'] = round
#                Tournament        Date         Series    Court Surface  \
# 0      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 1      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2      AAPT Championships  2001-01-01  International  Outdoor    Hard
# 3               TATA Open  2001-01-01  International  Outdoor    Hard
# 4               TATA Open  2001-01-01  International  Outdoor    Hard
# ...                   ...         ...            ...      ...     ...
# 12034    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12035    Shanghai Masters  2024-10-08        ATP1000  Outdoor    Hard
# 12036    Shanghai Masters  2024-10-09        ATP1000  Outdoor    Hard
# 12037    Shanghai Masters  2024-10-10        ATP1000  Outdoor    Hard
# 12038    Shanghai Masters  2024-10-13        ATP1000  Outdoor    Hard
#
#                Round  Best of       Player_1        Player_2          Winner  \
# 0          2nd Round        3      Hewitt L.         Phau B.       Hewitt L.
# 1      Quarterfinals        3   Johansson T.       Henman T.       Henman T.
# 2      Quarterfinals        3       Massu N.     Ljubicic I.        Massu N.
# 3          1st Round        3     Robredo T.         Paes L.      Robredo T.
# 4          1st Round        3  Kratochvil M.  Vinciguerra A.  Vinciguerra A.
# ...              ...      ...            ...             ...             ...
# 12034      3rd Round        3    Dimitrov G.      Popyrin A.     Dimitrov G.
# 12035      3rd Round        3  Griekspoor T.       Zverev A.       Zverev A.
# 12036      4th Round        3   Tsitsipas S.     Medvedev D.     Medvedev D.
# 12037  Quarterfinals        3     Alcaraz C.       Machac T.       Machac T.
# 12038      The Final        3      Sinner J.     Djokovic N.       Sinner J.
#
#        ...  name_first_player2  name_last_player2  hand_player2  dob_player2  \
# 0      ...               Bjorn               Phau             R   1979-10-04
# 1      ...                 Tim             Henman             R   1974-09-06
# 2      ...                Ivan           Ljubicic             R   1979-03-19
# 3      ...             Leander               Paes             R   1973-06-17
# 4      ...             Andreas        Vinciguerra             L   1981-02-19
# ...    ...                 ...                ...           ...          ...
# 12034  ...              Alexei            Popyrin             R   1999-08-05
# 12035  ...           Alexander             Zverev             R   1997-04-20
# 12036  ...              Daniil           Medvedev             R   1996-02-11
# 12037  ...               Tomas             Machac             R   2000-10-13
# 12038  ...               Novak           Djokovic             R   1987-05-22
#
#        ioc_player2  height_player2 Relevant Player age_player1 age_player2  \
# 0              GER           175.0               1          19          21
# 1              GBR           185.0               1          25          26
# 2              CRO           193.0               1          21          21
# 3              IND           178.0               2          18          27
# 4              SWE           180.0               1          21          19
# ...            ...             ...             ...         ...         ...
# 12034          AUS           196.0               2          33          25
# 12035          GER           198.0               2          28          27
# 12036          RUS           198.0               1          26          28
# 12037          CZE           183.0               2          21          23
# 12038          SRB           188.0               1          23          37
#
#       round
# 0         2
# 1         3
# 2         3
# 3         1
# 4         1
# ...     ...
# 12034     3
# 12035     3
# 12036     4
# 12037     5
# 12038     6
#
# [10598 rows x 33 columns]

# %%
player_matches_df['Score'] = player_matches_df['Score'].apply(lambda score: score.split())
player_matches_df['T'] = player_matches_df.apply(lambda row: int(row['Score'][0][0 if row['Relevant Player']=='1' else -1]=='7'), axis=1)
player_matches_df['Y'] = player_matches_df.apply(lambda row: int(int(row['Score'][1][0]) > int(row['Score'][1][-1])) 
                                                if row['Relevant Player']==1
                                                else int(int(row['Score'][1][0]) < int(row['Score'][1][-1])), axis=1)

player_matches_df.head(5)
# Out:
# C:\Users\ordad\AppData\Local\Temp\ipykernel_10164\3499783436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_matches_df['Score'] = player_matches_df['Score'].apply(lambda score: score.split())
# C:\Users\ordad\AppData\Local\Temp\ipykernel_10164\3499783436.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_matches_df['T'] = player_matches_df.apply(lambda row: int(row['Score'][0][0 if row['Relevant Player']=='1' else -1]=='7'), axis=1)
# C:\Users\ordad\AppData\Local\Temp\ipykernel_10164\3499783436.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_matches_df['Y'] = player_matches_df.apply(lambda row: int(int(row['Score'][1][0]) > int(row['Score'][1][-1]))
#            Tournament        Date         Series    Court Surface  \
# 0  AAPT Championships  2001-01-01  International  Outdoor    Hard
# 1  AAPT Championships  2001-01-01  International  Outdoor    Hard
# 2  AAPT Championships  2001-01-01  International  Outdoor    Hard
# 3           TATA Open  2001-01-01  International  Outdoor    Hard
# 4           TATA Open  2001-01-01  International  Outdoor    Hard
#
#            Round  Best of       Player_1        Player_2          Winner  ...  \
# 0      2nd Round        3      Hewitt L.         Phau B.       Hewitt L.  ...
# 1  Quarterfinals        3   Johansson T.       Henman T.       Henman T.  ...
# 2  Quarterfinals        3       Massu N.     Ljubicic I.        Massu N.  ...
# 3      1st Round        3     Robredo T.         Paes L.      Robredo T.  ...
# 4      1st Round        3  Kratochvil M.  Vinciguerra A.  Vinciguerra A.  ...
#
#    hand_player2  dob_player2  ioc_player2  height_player2  Relevant Player  \
# 0             R   1979-10-04          GER           175.0                1
# 1             R   1974-09-06          GBR           185.0                1
# 2             R   1979-03-19          CRO           193.0                1
# 3             R   1973-06-17          IND           178.0                2
# 4             L   1981-02-19          SWE           180.0                1
#
#    age_player1 age_player2 round  T  Y
# 0           19          21     2  1  1
# 1           25          26     3  1  1
# 2           21          21     3  1  1
# 3           18          27     1  0  0
# 4           21          19     1  1  0
#
# [5 rows x 35 columns]

# %%
numeric_df = player_matches_df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                  Best of    Rank_1    Rank_2     Pts_1     Pts_2     Odd_1  \
# Best of         1.000000 -0.024747 -0.025052  0.065434  0.071263  0.140025
# Rank_1         -0.024747  1.000000  0.085636 -0.327855 -0.095469  0.221131
# Rank_2         -0.025052  0.085636  1.000000 -0.078493 -0.317652 -0.240764
# Pts_1           0.065434 -0.327855 -0.078493  1.000000  0.294826 -0.161841
# Pts_2           0.071263 -0.095469 -0.317652  0.294826  1.000000  0.527020
# Odd_1           0.140025  0.221131 -0.240764 -0.161841  0.527020  1.000000
# Odd_2           0.120639 -0.238978  0.234610  0.522602 -0.163784 -0.348455
# height_player1  0.002261 -0.041193 -0.005958  0.107804  0.072629 -0.051928
# height_player2 -0.007278 -0.000537 -0.056561  0.079742  0.103018  0.046591
# age_player1     0.010466 -0.043336  0.010045  0.071327  0.063502  0.008299
# age_player2     0.005056  0.004269 -0.023299  0.063439  0.071688  0.003974
# round           0.022738 -0.208517 -0.214678  0.299842  0.296656  0.032005
# T              -0.008073  0.059289 -0.044062 -0.086708  0.064565  0.130377
# Y              -0.012215  0.018059 -0.006694 -0.016471 -0.002688 -0.009224
#
#                    Odd_2  height_player1  height_player2  age_player1  \
# Best of         0.120639        0.002261       -0.007278     0.010466
# Rank_1         -0.238978       -0.041193       -0.000537    -0.043336
# Rank_2          0.234610       -0.005958       -0.056561     0.010045
# Pts_1           0.522602        0.107804        0.079742     0.071327
# Pts_2          -0.163784        0.072629        0.103018     0.063502
# Odd_1          -0.348455       -0.051928        0.046591     0.008299
# Odd_2           1.000000        0.050916       -0.059036     0.012663
# height_player1  0.050916        1.000000        0.032842    -0.003970
# height_player2 -0.059036        0.032842        1.000000     0.048065
# age_player1     0.012663       -0.003970        0.048065     1.000000
# age_player2    -0.006978        0.025003       -0.009485     0.044275
# round           0.020140        0.078868        0.087926    -0.018683
# T              -0.139256       -0.014344        0.029753    -0.005247
# Y              -0.017456        0.009472       -0.001101    -0.016014
#
#                 age_player2     round         T         Y
# Best of            0.005056  0.022738 -0.008073 -0.012215
# Rank_1             0.004269 -0.208517  0.059289  0.018059
# Rank_2            -0.023299 -0.214678 -0.044062 -0.006694
# Pts_1              0.063439  0.299842 -0.086708 -0.016471
# Pts_2              0.071688  0.296656  0.064565 -0.002688
# Odd_1              0.003974  0.032005  0.130377 -0.009224
# Odd_2             -0.006978  0.020140 -0.139256 -0.017456
# height_player1     0.025003  0.078868 -0.014344  0.009472
# height_player2    -0.009485  0.087926  0.029753 -0.001101
# age_player1        0.044275 -0.018683 -0.005247 -0.016014
# age_player2        1.000000 -0.019409  0.006361 -0.000145
# round             -0.019409  1.000000  0.002760  0.008339
# T                  0.006361  0.002760  1.000000  0.002135
# Y                 -0.000145  0.008339  0.002135  1.000000

# %%
feature_df = player_matches_df[['Court', 'Surface', 'round', 'Best of',
                                'Rank_1', 'Rank_2', 'Pts_1', 'Pts_2',
                                'Odd_1', 'Odd_2',
                                'hand_player1', 'height_player1',
                                'hand_player2',
                                'height_player2', 'Relevant Player',
                                'age_player1', 'age_player2', 'T', 'Y']]

def switch_columns(row):
    if row['Relevant Player'] == '2':
        row['hand_player1'], row['hand_player2'] = row['hand_player2'], row['hand_player1']
        row['height_player1'], row['height_player2'] = row['height_player2'], row['height_player1']
        row['age_player1'], row['age_player2'] = row['age_player2'], row['age_player1']
        row['Rank_1'], row['Rank_2'] = row['Rank_2'], row['Rank_1']
        row['Pts_1'], row['Pts_2'] = row['Pts_2'], row['Pts_1']
        row['Odd_1'], row['Odd_2'] = row['Odd_2'], row['Odd_1']
    return row

feature_df = feature_df.apply(switch_columns, axis=1)
# feature_df.columns = ['Court', 'Surface', 'round', 'Best of',
#                     'Rank_1', 'Rank_2', 'Pts_1', 'Pts_2',
#                     'Odd_1', 'Odd_2',
#                     'hand_player1', 'height_player1',
#                     'hand_player2',
#                     'height_player2', 'Relevant Player',
#                     'age_player1', 'age_player2', 'T', 'Y']
feature_df = feature_df.drop(columns=['Relevant Player'])

feature_df.to_csv('Final_Data/feature_df_second_pre_process.csv')
feature_df
# Out:
#          Court Surface  round  Best of  Rank_1  Rank_2  Pts_1  Pts_2  \
# 0      Outdoor    Hard      2        3       7     208     -1     -1
# 1      Outdoor    Hard      3        3      39      10     -1     -1
# 2      Outdoor    Hard      3        3      87      91     -1     -1
# 3      Outdoor    Hard      1        3     131     188     -1     -1
# 4      Outdoor    Hard      1        3      93      52     -1     -1
# ...        ...     ...    ...      ...     ...     ...    ...    ...
# 12034  Outdoor    Hard      3        3      10      24   3840   1825
# 12035  Outdoor    Hard      3        3      40       3   1305   6705
# 12036  Outdoor    Hard      4        3      12       5   3390   5375
# 12037  Outdoor    Hard      5        3       2      33   7010   1449
# 12038  Outdoor    Hard      6        3       4       4  11010   5560
#
#           Odd_1     Odd_2 hand_player1  height_player1 hand_player2  \
# 0      1.130000  5.500000            R           180.0            R
# 1      2.662500  1.367500            R           180.0            R
# 2      1.916667  1.653333            R           183.0            R
# 3      2.000000  1.450000            R           180.0            R
# 4      2.333333  1.410000            R           185.0            L
# ...         ...       ...          ...             ...          ...
# 12034  1.670000  2.200000            R           188.0            R
# 12035  4.330000  1.220000            R           188.0            R
# 12036  3.000000  1.400000            R           193.0            R
# 12037  1.080000  8.000000            R           185.0            R
# 12038  1.400000  3.000000            R           188.0            R
#
#        height_player2  age_player1  age_player2  T  Y
# 0               175.0           19           21  1  1
# 1               185.0           25           26  1  1
# 2               193.0           21           21  1  1
# 3               178.0           18           27  0  0
# 4               180.0           21           19  1  0
# ...               ...          ...          ... .. ..
# 12034           196.0           33           25  0  0
# 12035           198.0           28           27  1  0
# 12036           198.0           26           28  1  0
# 12037           183.0           21           23  1  1
# 12038           188.0           23           37  0  1
#
# [10598 rows x 18 columns]
